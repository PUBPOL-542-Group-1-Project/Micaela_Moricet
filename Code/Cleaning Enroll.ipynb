# %%
#collecting data from github repository

import pandas as pd

location='https://github.com/PUBPOL-542-Group-1-Project/Micaela_Moricet/raw/main/datafiles/Report_Card_Enrollment_2018-19_School_Year.xlsm'
enroll=pd.read_excel(location)

# %%
enroll.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19866 entries, 0 to 19865
# Data columns (total 45 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   SchoolYear                               19866 non-null  object
#  1   OrganizationLevel                        19866 non-null  object
#  2   County                                   19866 non-null  object
#  3   ESDName                                  19542 non-null  object
#  4   ESDOrganizationID                        19526 non-null  float64
#  5   DistrictCode                             19850 non-null  float64
#  6   DistrictName                             19866 non-null  object
#  7   DistrictOrganizationId                   19850 non-null  float64
#  8   SchoolCode                               15474 non-null  float64
#  9   SchoolName                               19866 non-null  object
# ...

# %%
en=enroll.copy()

# %%
#drop variables we don't need
en.drop(en.iloc[:,[0,1,3,4,7,10]], axis=1, inplace=True)

# %%
en.drop(en.iloc[:,34:44], axis=1, inplace=True)

# %%
en
# Out:
#          County  DistrictCode            DistrictName  SchoolCode  \
# 0      Multiple           NaN             State Total         NaN
# 1      Multiple           NaN             State Total         NaN
# 2      Multiple           NaN             State Total         NaN
# 3      Multiple           NaN             State Total         NaN
# 4      Multiple           NaN             State Total         NaN
# ...         ...           ...                     ...         ...
# 19861    Yakima       39205.0  Zillah School District         NaN
# 19862    Yakima       39205.0  Zillah School District         NaN
# 19863    Yakima       39205.0  Zillah School District         NaN
# 19864    Yakima       39205.0  Zillah School District         NaN
# 19865    Yakima       39205.0  Zillah School District         NaN
#
#            SchoolName CurrentSchoolType        GradeLevel  All Students  \
# 0         State Total               NaN        10th Grade         83402
# ...

# %%
#keep grade 12 only

#how many
en.GradeLevel.value_counts()
# Out:
# AllGrades                2711
# 5th Grade                1568
# 3rd Grade                1568
# 2nd Grade                1566
# 4th Grade                1561
# 1st Grade                1554
# Kindergarten             1534
# Pre-Kindergarten         1117
# 6th Grade                1108
# 8th Grade                 956
# 12th Grade                951
# 7th Grade                 947
# 11th Grade                935
# 10th Grade                894
# 9th Grade                 850
# Half-day Kindergarten      46
# Name: GradeLevel, dtype: int64

# %%
enn=en.copy()

# %%
enn=enn[(enn.GradeLevel== '12th Grade')]

# %%
#verify
enn.GradeLevel.value_counts()
# Out:
# 12th Grade    951
# Name: GradeLevel, dtype: int64

# %%
#drop rows with state totals

enn=enn[~enn.County.str.contains("Multiple")]

# %%
enn.shape
# Out:
# (950, 34)

# %%
#drop rows if SchoolName =District Total
to_drop=['District Total']
enn=enn[~enn['SchoolName'].isin(to_drop)]

# %%
enn
# Out:
#              County  DistrictCode              DistrictName  SchoolCode  \
# 36     Grays Harbor       14005.0  Aberdeen School District      5514.0
# 43     Grays Harbor       14005.0  Aberdeen School District      4267.0
# 48     Grays Harbor       14005.0  Aberdeen School District      3857.0
# 55     Grays Harbor       14005.0  Aberdeen School District      3476.0
# 88     Grays Harbor       14005.0  Aberdeen School District      5208.0
# ...             ...           ...                       ...         ...
# 15399        Yakima       39007.0    Yakima School District      5355.0
# 15403        Yakima       39007.0    Yakima School District      5224.0
# 15452      Thurston       34002.0      Yelm School District      1627.0
# 15457      Thurston       34002.0      Yelm School District      2633.0
# 15480        Yakima       39205.0    Zillah School District      2240.0
#
#                                               SchoolName CurrentSchoolType  \
# ...

# %%
enn.describe()
# Out:
#        DistrictCode   SchoolCode  All Students      Female    Gender X  \
# count    682.000000   682.000000    682.000000  682.000000  682.000000
# mean   22287.662757  3490.385630    133.617302   64.545455    0.200880
# std    10392.702138  1327.507708    161.066021   79.612213    4.177676
# min     1109.000000  1500.000000      1.000000    0.000000    0.000000
# 25%    17001.000000  2330.250000     14.000000    6.000000    0.000000
# 50%    21302.000000  3312.500000     55.000000   25.500000    0.000000
# 75%    31279.750000  5031.750000    222.000000  108.750000    0.000000
# max    39209.000000  5961.000000    843.000000  497.000000  109.000000
#
#              Male  American Indian/ Alaskan Native       Asian  \
# count  682.000000                       682.000000  682.000000
# mean    68.870968                         1.803519   10.596774
# std     82.233297                         3.983385   25.450886
# min      0.000000                         0.000000    0.000000
# ...

# %%
enn.to_csv('enroll.csv', index=False)
